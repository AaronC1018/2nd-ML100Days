# %% [markdown]
# ### 作業1:
#
# US Mass Shootings - https://www.kaggle.com/zusmani/us-mass-shootings-last-50-years
#
# 1. 你選的這組資料為何重要<br>
#     美國幾乎每天都有Mass Shooting發生, 有太多的無辜老百姓受害, 如果能在這些案件的統計數據   中找出較可能犯罪者的特徵或其他蛛絲馬跡,就能提早預防、制止,以減少無辜的人民受害。
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)<br>
#     資料提供者-Zeeshan-ul-hassan Usmani。
#     蒐集方式是提供者自行去各大相關網站收集資料及彙整,
#     主要網站有: Wikipedia, Mother Jones, Stanford, USA Today 。
# 3. 蒐集而來的資料型態為何<br>
#     資料型態-結構化的資料形式（Location,Date,Summary,Fatalities,Injured,Total victims	,Mental Health Issues,Race,Gender,Latitude,Longitude)。
#     檔案的格式是CSV檔案。
# 4. 這組資料想解決的問題如何評估<br>
#     先找出槍手在精神疾病這項欄位的眾數,而後在加入地區、時間甚至是種族資料的相似點,去找出可能成為槍手的淺在族群。
#
# ### 作業2:
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)<br>
#     我認為以載客車隊來說,最重要的問題是客戶滿意度,客戶滿意度可從司機態度、車輛外觀及整潔、行車安全、mobile app是否好操作以及付款方式是否滿足客戶需求這幾項的評分來評估,當有了這些資料後,可進而去找出顧客對車隊較不滿意的地方,並進行改善,以致提升滿意度和車隊品牌形象,進而帶動業績提升。
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)<br>
#     司機態度、車輛外觀及整潔、行車安全、mobile app是否好操作以及付款方式是否滿足客戶,這幾項資料都會對顧客滿意度有所直接性的影響。
#     資料蒐集：
#     會以問卷調查方式蒐集資料,乘客又可分為一般支付以及使用APP管道支付兩個族群。
#     一般支付的乘客可能會詢問是否願意使用車上觸控螢幕填寫問卷,並在填寫完成後贈與下次乘車折抵十元抵用卷,以增加填寫意願。
#     使用APP管道支付乘客則可以在搭車完後立即使用手機填寫問卷,並且在完成後,app會直接給予十元抵用卷供下次使用。
# 3. 蒐集而來的資料型態為何<br>
#     資料型態會是屬量的結構化資料,問卷上的項目都會以1到10分的範圍給顧客評分。
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)<br>
#     在收集到資料之後,先計算顧客最不滿意的三個項目,並且立即改善車隊在這三個項目的表現,而後觀察是否在改善後,業績有明顯的提升。
#
# ### 作業3:
#
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,yhat):
    return sum((y-yhat)**2)/len(y)

def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae= sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 239.540
# The Mean absolute error is 12.333
